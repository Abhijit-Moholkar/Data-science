# %% [markdown]
# # Analysis of IPL Dataset

# %% [markdown]
# ***Exploratory Data Analysis***
#
#
# 1.   Exploratory data analysis is an approach to analyzing data sets to summarize their main characteristics, often with visual methods.
# 2.   In data science, it is often used as a starting point to gain insights about the dataset and understanding the features of the dataset.
# 3.  Data visualization is a very important part in data science as data nowadays is like oil, it increases continuosly and if it is not represented properly, valuable points/insights may be lost.

# %% [markdown]
# ![ipl.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ##### Import modules for processing
# pandas module for data processing and
# matplotlib for data visualization

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### Read the file

# %%
df = pd.read_csv('matches.csv')
df
# Out:
#         id    Season           city     date                        team1  \
# 0        1  IPL-2017      Hyderabad   5/4/17          Sunrisers Hyderabad
# 1        2  IPL-2017           Pune   6/4/17               Mumbai Indians
# 2        3  IPL-2017         Rajkot   7/4/17                Gujarat Lions
# 3        4  IPL-2017         Indore   8/4/17       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore   8/4/17  Royal Challengers Bangalore
# ..     ...       ...            ...      ...                          ...
# 751  11347  IPL-2019         Mumbai   5/5/19        Kolkata Knight Riders
# 752  11412  IPL-2019        Chennai   7/5/19          Chennai Super Kings
# 753  11413  IPL-2019  Visakhapatnam   8/5/19          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10/5/19               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12/5/19               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %% [markdown]
# ##### list out names of columns

# %%
print(df.columns.tolist())
# Out:
# ['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2', 'umpire3']

# %% [markdown]
# ##### Fetch top 3 records
# It can be done using head method or slicing

# %%
df.head(3)
# Out:
#    id    Season       city    date                team1  \
# 0   1  IPL-2017  Hyderabad  5/4/17  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  6/4/17       Mumbai Indians
# 2   3  IPL-2017     Rajkot  7/4/17        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %%
df[:3]
# Out:
#    id    Season       city    date                team1  \
# 0   1  IPL-2017  Hyderabad  5/4/17  Sunrisers Hyderabad
# 1   2  IPL-2017       Pune  6/4/17       Mumbai Indians
# 2   3  IPL-2017     Rajkot  7/4/17        Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
# 2  normal           0   Kolkata Knight Riders            0              10
#
#   player_of_match                                      venue         umpire1  \
# ...

# %% [markdown]
# ##### fetch last 3 records
# It can be done using tail method or slicing

# %%
df.tail(3)
# Out:
#         id    Season           city     date                team1  \
# 753  11413  IPL-2019  Visakhapatnam   8/5/19  Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10/5/19       Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12/5/19       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %%
df[-3:]
# Out:
#         id    Season           city     date                team1  \
# 753  11413  IPL-2019  Visakhapatnam   8/5/19  Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10/5/19       Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12/5/19       Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 753           0       Delhi Capitals            0               2
# 754           0  Chennai Super Kings            0               6
# 755           0       Mumbai Indians            1               0
#
#     player_of_match                               venue        umpire1  \
# 753         RR Pant                    ACA-VDCA Stadium            NaN
# ...

# %% [markdown]
# ##### How many rows and columns present?

# %%
print(f"Total number of records in dataframe are: {df.shape[0]}")     
print(f"Total number of columns in dataframe are: {df.shape[1]}")
# Out:
# Total number of records in dataframe are: 756
# Total number of columns in dataframe are: 18

# %% [markdown]
# ##### List out the names of columns

# %%
print(f"list of data frame columns are: {df.columns.tolist()}")
# Out:
# list of data frame columns are: ['id', 'Season', 'city', 'date', 'team1', 'team2', 'toss_winner', 'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs', 'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2', 'umpire3']

# %% [markdown]
# ##### check the abstract summary of data
# To analyse number of non null records column wise and their data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   Season           756 non-null    object
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %% [markdown]
# ##### check the missing values
# Missing values are filled by NaN. so count number of missing values in each column

# %%
df.isna().sum().values.sum()      # To check number of missing values in whole dataframe
# Out:
# 656

# %%
df.isna().sum()                   # To check number of missing values in each column
# Out:
# id                   0
# Season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %% [markdown]
# ##### check descriptive statistics
# Descriptive statistics is applicable on numeric columns. It gives statistical analysis of data

# %%
df.describe()
# Out:
#                  id  dl_applied  win_by_runs  win_by_wickets
# count    756.000000  756.000000   756.000000      756.000000
# mean    1792.178571    0.025132    13.283069        3.350529
# std     3464.478148    0.156630    23.471144        3.387963
# min        1.000000    0.000000     0.000000        0.000000
# 25%      189.750000    0.000000     0.000000        0.000000
# 50%      378.500000    0.000000     0.000000        4.000000
# 75%      567.250000    0.000000    19.000000        6.000000
# max    11415.000000    1.000000   146.000000       10.000000

# %% [markdown]
# ##### check the data of any column

# %%
df.city                   # Access any column of data frame as a series and check its data type
# Out:
# 0          Hyderabad
# 1               Pune
# 2             Rajkot
# 3             Indore
# 4          Bangalore
#            ...
# 751           Mumbai
# 752          Chennai
# 753    Visakhapatnam
# 754    Visakhapatnam
# 755        Hyderabad
# Name: city, Length: 756, dtype: object

# %%
df[['city']]              # Access any column of data frame as a series and check its data type
# Out:
#               city
# 0        Hyderabad
# 1             Pune
# 2           Rajkot
# 3           Indore
# 4        Bangalore
# ..             ...
# 751         Mumbai
# 752        Chennai
# 753  Visakhapatnam
# 754  Visakhapatnam
# 755      Hyderabad
#
# [756 rows x 1 columns]

# %% [markdown]
# ##### Fetch City and result column
# It gives result as dataframe having only city and result columns

# %%
df[['city','result']]
# Out:
#               city  result
# 0        Hyderabad  normal
# 1             Pune  normal
# 2           Rajkot  normal
# 3           Indore  normal
# 4        Bangalore  normal
# ..             ...     ...
# 751         Mumbai  normal
# 752        Chennai  normal
# 753  Visakhapatnam  normal
# 754  Visakhapatnam  normal
# 755      Hyderabad  normal
#
# [756 rows x 2 columns]

# %% [markdown]
# ##### Fetch the data of Season 2017

# %%
df.groupby('Season').get_group('IPL-2017')
# Out:
#     id    Season        city        date                        team1  \
# 0    1  IPL-2017   Hyderabad      5/4/17          Sunrisers Hyderabad
# 1    2  IPL-2017        Pune      6/4/17               Mumbai Indians
# 2    3  IPL-2017      Rajkot      7/4/17                Gujarat Lions
# 3    4  IPL-2017      Indore      8/4/17       Rising Pune Supergiant
# 4    5  IPL-2017   Bangalore      8/4/17  Royal Challengers Bangalore
# 5    6  IPL-2017   Hyderabad      9/4/17                Gujarat Lions
# 6    7  IPL-2017      Mumbai      9/4/17        Kolkata Knight Riders
# 7    8  IPL-2017      Indore     10/4/17  Royal Challengers Bangalore
# 8    9  IPL-2017        Pune     11/4/17             Delhi Daredevils
# 9   10  IPL-2017      Mumbai     12/4/17          Sunrisers Hyderabad
# 10  11  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# ...

# %%
df[df['Season'] == 'IPL-2017']
# Out:
#     id    Season        city        date                        team1  \
# 0    1  IPL-2017   Hyderabad      5/4/17          Sunrisers Hyderabad
# 1    2  IPL-2017        Pune      6/4/17               Mumbai Indians
# 2    3  IPL-2017      Rajkot      7/4/17                Gujarat Lions
# 3    4  IPL-2017      Indore      8/4/17       Rising Pune Supergiant
# 4    5  IPL-2017   Bangalore      8/4/17  Royal Challengers Bangalore
# 5    6  IPL-2017   Hyderabad      9/4/17                Gujarat Lions
# 6    7  IPL-2017      Mumbai      9/4/17        Kolkata Knight Riders
# 7    8  IPL-2017      Indore     10/4/17  Royal Challengers Bangalore
# 8    9  IPL-2017        Pune     11/4/17             Delhi Daredevils
# 9   10  IPL-2017      Mumbai     12/4/17          Sunrisers Hyderabad
# 10  11  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# ...

# %%
df.query("Season == 'IPL-2017'")
# Out:
#     id    Season        city        date                        team1  \
# 0    1  IPL-2017   Hyderabad      5/4/17          Sunrisers Hyderabad
# 1    2  IPL-2017        Pune      6/4/17               Mumbai Indians
# 2    3  IPL-2017      Rajkot      7/4/17                Gujarat Lions
# 3    4  IPL-2017      Indore      8/4/17       Rising Pune Supergiant
# 4    5  IPL-2017   Bangalore      8/4/17  Royal Challengers Bangalore
# 5    6  IPL-2017   Hyderabad      9/4/17                Gujarat Lions
# 6    7  IPL-2017      Mumbai      9/4/17        Kolkata Knight Riders
# 7    8  IPL-2017      Indore     10/4/17  Royal Challengers Bangalore
# 8    9  IPL-2017        Pune     11/4/17             Delhi Daredevils
# 9   10  IPL-2017      Mumbai     12/4/17          Sunrisers Hyderabad
# 10  11  IPL-2017     Kolkata  13-04-2017              Kings XI Punjab
# 11  12  IPL-2017   Bangalore  14-04-2017  Royal Challengers Bangalore
# ...

# %% [markdown]
# ##### How many matches played in season 2018

# %%
df.groupby('Season').get_group('IPL-2018').shape[0]
# Out:
# 60

# %%
(df.Season == 'IPL-2018').sum()
# Out:
# 60

# %%
len(df[df.Season == 'IPL-2018'])
# Out:
# 60

# %%
df.query("Season == 'IPL-2018'").shape[0]
# Out:
# 60

# %%
(df.Season == 'IPL-2018').value_counts()
# Out:
# False    696
# True      60
# Name: Season, dtype: int64

# %% [markdown]
# ##### How many matches played at Rajiv Gandhi International Stadium, Uppal

# %%
df.groupby('venue').get_group('Rajiv Gandhi International Stadium, Uppal').shape[0]
# Out:
# 56

# %%
df[df.venue == 'Rajiv Gandhi International Stadium, Uppal'].shape[0]
# Out:
# 56

# %%
len(df[df.venue == 'Rajiv Gandhi International Stadium, Uppal'])
# Out:
# 56

# %%
(df.venue == 'Rajiv Gandhi International Stadium, Uppal').value_counts()
# Out:
# False    700
# True      56
# Name: venue, dtype: int64

# %%
df.query("venue == 'Rajiv Gandhi International Stadium, Uppal'").shape[0]
# Out:
# 56

# %%
df.venue.value_counts()['Rajiv Gandhi International Stadium, Uppal']
# Out:
# 56

# %%
df.venue.value_counts().loc['Rajiv Gandhi International Stadium, Uppal']
# Out:
# 56

# %% [markdown]
# ##### Show the total seasons in dataset

# %%
print(f"Season list of IPL is: \n{df.Season.unique().tolist()}")
# Out:
# Season list of IPL is:
# ['IPL-2017', 'IPL-2008', 'IPL-2009', 'IPL-2010', 'IPL-2011', 'IPL-2012', 'IPL-2013', 'IPL-2014', 'IPL-2015', 'IPL-2016', 'IPL-2018', 'IPL-2019']

# %% [markdown]
# ##### How many seasons data we have?

# %%
df.Season.nunique()
# Out:
# 12

# %% [markdown]
# ### Let us get some basic stats #
# ##### How many Number of matches played so far

# %%
df.shape[0]
# Out:
# 756

# %% [markdown]
# ##### plot the count of matches played each season

# %%
df.groupby('Season').count()['id'].plot(kind = 'bar')
# Out:
# <AxesSubplot:xlabel='Season'>

# %% [markdown]
# ##### Number of Matches played in each venue

# %%
df.venue.value_counts()
# Out:
# Eden Gardens                                            77
# M Chinnaswamy Stadium                                   73
# Wankhede Stadium                                        73
# Feroz Shah Kotla                                        67
# Rajiv Gandhi International Stadium, Uppal               56
# MA Chidambaram Stadium, Chepauk                         49
# Sawai Mansingh Stadium                                  47
# Punjab Cricket Association Stadium, Mohali              35
# Maharashtra Cricket Association Stadium                 21
# Subrata Roy Sahara Stadium                              17
# Dr DY Patil Sports Academy                              17
# Kingsmead                                               15
# Punjab Cricket Association IS Bindra Stadium, Mohali    14
# SuperSport Park                                         12
# Sardar Patel Stadium, Motera                            12
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %% [markdown]
# ##### Top 5 venues and most matches played

# %%
df.venue.value_counts().head()
# Out:
# Eden Gardens                                 77
# M Chinnaswamy Stadium                        73
# Wankhede Stadium                             73
# Feroz Shah Kotla                             67
# Rajiv Gandhi International Stadium, Uppal    56
# Name: venue, dtype: int64

# %%
df.groupby('venue').count().sort_values("id",ascending = False)[:5].index.tolist()
# Out:
# ['Eden Gardens',
#  'Wankhede Stadium',
#  'M Chinnaswamy Stadium',
#  'Feroz Shah Kotla',
#  'Rajiv Gandhi International Stadium, Uppal']

# %% [markdown]
# ##### find top 5 match playing teams

# %%
t1 = df.groupby('team1').size()          # Number of maches played by each team as team1
t1
# Out:
# team1
# Chennai Super Kings             89
# Deccan Chargers                 43
# Delhi Capitals                   6
# Delhi Daredevils                72
# Gujarat Lions                   14
# Kings XI Punjab                 91
# Kochi Tuskers Kerala             7
# Kolkata Knight Riders           83
# Mumbai Indians                 101
# Pune Warriors                   20
# Rajasthan Royals                67
# Rising Pune Supergiant           8
# Rising Pune Supergiants          7
# Royal Challengers Bangalore     85
# Sunrisers Hyderabad             63
# dtype: int64

# %%
t2 = df.groupby('team2').size()            # Number of matches played by each team as team2
t2
# Out:
# team2
# Chennai Super Kings            75
# Deccan Chargers                32
# Delhi Capitals                 10
# Delhi Daredevils               89
# Gujarat Lions                  16
# Kings XI Punjab                85
# Kochi Tuskers Kerala            7
# Kolkata Knight Riders          95
# Mumbai Indians                 86
# Pune Warriors                  26
# Rajasthan Royals               80
# Rising Pune Supergiant          8
# Rising Pune Supergiants         7
# Royal Challengers Bangalore    95
# Sunrisers Hyderabad            45
# dtype: int64

# %%
(t1+t2).sort_values(ascending = False)[:5]       # Total number of matches played by each team as team1 or team2
# Out:
# team1
# Mumbai Indians                 187
# Royal Challengers Bangalore    180
# Kolkata Knight Riders          178
# Kings XI Punjab                176
# Chennai Super Kings            164
# dtype: int64

# %% [markdown]
# ##### Which Team won the most of tosses

# %%
df.groupby('toss_winner').count().sort_values("id",ascending = False).index[0]
# Out:
# 'Mumbai Indians'

# %%
df.toss_winner.value_counts().index[0]
# Out:
# 'Mumbai Indians'

# %%
df.toss_winner.value_counts().head(1)
# Out:
# Mumbai Indians    98
# Name: toss_winner, dtype: int64

# %% [markdown]
# ##### who won the final match of season 2019?

# %%
df.groupby('Season').get_group('IPL-2019')['winner'].tail(1)
# Out:
# 755    Mumbai Indians
# Name: winner, dtype: object

# %%
df[df.Season == 'IPL-2019'].winner.values[-1]
# Out:
# 'Mumbai Indians'

# %%
df[df.Season == 'IPL-2019'].winner.tail(1)
# Out:
# 755    Mumbai Indians
# Name: winner, dtype: object

# %% [markdown]
# ##### who is the winner of season 2018

# %%
df.groupby('Season').get_group('IPL-2018')['winner'].tail(1)
# Out:
# 695    Chennai Super Kings
# Name: winner, dtype: object

# %%
df[df.Season == 'IPL-2018'].winner.values[-1]
# Out:
# 'Chennai Super Kings'

# %%
df[df.Season == 'IPL-2018'].winner.tail(1)
# Out:
# 695    Chennai Super Kings
# Name: winner, dtype: object

# %% [markdown]
# ##### Number of Matches played by each Team

# %%
t1 = df.team1.value_counts()
t1
# Out:
# Mumbai Indians                 101
# Kings XI Punjab                 91
# Chennai Super Kings             89
# Royal Challengers Bangalore     85
# Kolkata Knight Riders           83
# Delhi Daredevils                72
# Rajasthan Royals                67
# Sunrisers Hyderabad             63
# Deccan Chargers                 43
# Pune Warriors                   20
# Gujarat Lions                   14
# Rising Pune Supergiant           8
# Kochi Tuskers Kerala             7
# Rising Pune Supergiants          7
# Delhi Capitals                   6
# Name: team1, dtype: int64

# %%
t2 = df.team2.value_counts()
t2
# Out:
# Royal Challengers Bangalore    95
# Kolkata Knight Riders          95
# Delhi Daredevils               89
# Mumbai Indians                 86
# Kings XI Punjab                85
# Rajasthan Royals               80
# Chennai Super Kings            75
# Sunrisers Hyderabad            45
# Deccan Chargers                32
# Pune Warriors                  26
# Gujarat Lions                  16
# Delhi Capitals                 10
# Rising Pune Supergiant          8
# Kochi Tuskers Kerala            7
# Rising Pune Supergiants         7
# Name: team2, dtype: int64

# %%
t1+t2                            # Total number of matches played by each team as team1 (t1) or team2 (t2)
# Out:
# Chennai Super Kings            164
# Deccan Chargers                 75
# Delhi Capitals                  16
# Delhi Daredevils               161
# Gujarat Lions                   30
# Kings XI Punjab                176
# Kochi Tuskers Kerala            14
# Kolkata Knight Riders          178
# Mumbai Indians                 187
# Pune Warriors                   46
# Rajasthan Royals               147
# Rising Pune Supergiant          16
# Rising Pune Supergiants         14
# Royal Challengers Bangalore    180
# Sunrisers Hyderabad            108
# dtype: int64

# %% [markdown]
# ##### Which Team won the most of tosses

# %%
df.toss_winner.value_counts().index[0]
# Out:
# 'Mumbai Indians'

# %% [markdown]
# ##### Show the % of toss_decision
# Toss decision is either bat or field

# %%
df.toss_decision.value_counts().plot(kind = 'pie',autopct = '%.f%%')
plt.show()

# %% [markdown]
# ##### How many matches MI won till now?

# %%
(df.winner == 'Mumbai Indians').sum()
# Out:
# 109

# %%
df[df.winner == 'Mumbai Indians'].shape[0]
# Out:
# 109

# %%
df.winner.value_counts()['Mumbai Indians']
# Out:
# 109

# %%
df.query("winner == 'Mumbai Indians'").shape[0]
# Out:
# 109

# %% [markdown]
# ##### How many matche played between MI and CSK

# %%
df.query("team1 == 'Mumbai Indians' and team2 =='Chennai Super Kings' or (team1 == 'Chennai Super Kings' and team2 =='Mumbai Indians')").shape[0]
# Out:
# 28

# %% [markdown]
# ##### Find out top 10 player_of_match from season 2013

# %%
print(df.groupby('Season').get_group('IPL-2013')['player_of_match'].value_counts().index.tolist()[:10])
# Out:
# ['MEK Hussey', 'A Mishra', 'CH Gayle', 'MS Dhoni', 'KA Pollard', 'V Kohli', 'AM Rahane', 'DA Miller', 'JP Faulkner', 'JH Kallis']

# %%
print(df[df.Season == 'IPL-2013']['player_of_match'].value_counts().head(10).index.tolist())
# Out:
# ['MEK Hussey', 'A Mishra', 'CH Gayle', 'MS Dhoni', 'KA Pollard', 'V Kohli', 'AM Rahane', 'DA Miller', 'JP Faulkner', 'JH Kallis']

# %%
print(df[df.Season == 'IPL-2013']['player_of_match'].value_counts()[:10].index.tolist())
# Out:
# ['MEK Hussey', 'A Mishra', 'CH Gayle', 'MS Dhoni', 'KA Pollard', 'V Kohli', 'AM Rahane', 'DA Miller', 'JP Faulkner', 'JH Kallis']

# %%
print(df.query("Season == 'IPL-2013'")['player_of_match'].value_counts()[:10].index.tolist())
# Out:
# ['MEK Hussey', 'A Mishra', 'CH Gayle', 'MS Dhoni', 'KA Pollard', 'V Kohli', 'AM Rahane', 'DA Miller', 'JP Faulkner', 'JH Kallis']

# %% [markdown]
# ##### How many times by Sachine Tendulkar received player_of _match award

# %%
df[df.player_of_match == 'SR Tendulkar'].shape[0]
# Out:
# 8

# %%
len(df.query("player_of_match == 'SR Tendulkar'"))
# Out:
# 8

# %%
(df.player_of_match == 'SR Tendulkar').sum()
# Out:
# 8

# %%
df.player_of_match.value_counts()['SR Tendulkar']
# Out:
# 8

# %%
df.player_of_match.value_counts().loc['SR Tendulkar']
# Out:
# 8

# %% [markdown]
# ##### Find out the count of total no of matches played in Mumbai and Delhi

# %%
df.query("city == 'Mumbai' or city == 'Delhi'").shape[0]
# Out:
# 175

# %% [markdown]
# ##### If my place is Pune and Team is Delhi Daredevils then how many times they won?

# %%
df.groupby('city').get_group('Pune')[df.groupby('city').get_group('Pune').winner == 'Delhi Daredevils'].shape[0]
# Out:
# 3

# %% [markdown]
# ##### What is the percentage of toss win for KKR

# %% [raw]
# Total number of matches played by KKR

# %%
df.query("team1 == 'Kolkata Knight Riders' or team2 == 'Kolkata Knight Riders'").shape[0]
# Out:
# 178

# %% [raw]
# Total number of times toss win by KKR

# %%
df[df.toss_winner == 'Kolkata Knight Riders'].shape[0]
# Out:
# 92

# %%
x=[92,178-92]

# %%
plt.pie(x,autopct = '%.f%%',labels = ['Win','Lost'])
plt.title("Toss winning status of KKR")
plt.show()

# %% [markdown]
# ##### What is the percentage of toss win for KKR and also by other team

# %%
y = df.query("team1 == 'Kolkata Knight Riders' or team2 == 'Kolkata Knight Riders'").toss_winner.value_counts()
y
# Out:
# Kolkata Knight Riders          92
# Mumbai Indians                 15
# Royal Challengers Bangalore    13
# Chennai Super Kings            11
# Kings XI Punjab                10
# Rajasthan Royals               10
# Delhi Daredevils                8
# Sunrisers Hyderabad             8
# Deccan Chargers                 4
# Gujarat Lions                   3
# Delhi Capitals                  2
# Rising Pune Supergiants         1
# Rising Pune Supergiant          1
# Name: toss_winner, dtype: int64

# %%
#plt.figure(fig_size == (10,8))
plt.pie(y,autopct = '%.f%%',labels = y.index,radius = 3)
plt.show()

# %% [raw]
# It represnts the percentage of toss winning of teams played with Kolkata Knight Riders

# %% [markdown]
# ##### To get the count of toss einning team against Kolkata Knight Riders

# %%
df1 = df.query("team1 == 'Kolkata Knight Riders' or team2 == 'Kolkata Knight Riders'")
df1
# Out:
#         id    Season       city        date                  team1  \
# 2        3  IPL-2017     Rajkot      7/4/17          Gujarat Lions
# 6        7  IPL-2017     Mumbai      9/4/17  Kolkata Knight Riders
# 10      11  IPL-2017    Kolkata  13-04-2017        Kings XI Punjab
# 13      14  IPL-2017    Kolkata  15-04-2017  Kolkata Knight Riders
# 17      18  IPL-2017      Delhi  17-04-2017       Delhi Daredevils
# ..     ...       ...        ...         ...                    ...
# 733  11329  IPL-2019  Hyderabad  21-04-2019  Kolkata Knight Riders
# 738  11334  IPL-2019    Kolkata  25-04-2019  Kolkata Knight Riders
# 742  11338  IPL-2019    Kolkata  28-04-2019  Kolkata Knight Riders
# 747  11343  IPL-2019     Mohali      3/5/19        Kings XI Punjab
# 751  11347  IPL-2019     Mumbai      5/5/19  Kolkata Knight Riders
#
#                      team2            toss_winner toss_decision  result  \
# 2    Kolkata Knight Riders  Kolkata Knight Riders         field  normal
# ...

# %%
sns.countplot(x = 'toss_winner',data = df1,orient = 'h')            
plt.xticks(ticks = range(13),labels = y.index,rotation = 90)
plt.show()

# %% [markdown]
# ##### plot %distribution of Mumbai Indians in its homeground which is obvious Mumbai

# %%
# Total matches played by Mumbai Indians at Mumbai 
p = df[df.city == 'Mumbai'].query("team1 == 'Mumbai Indians' or team2 == 'Mumbai Indians'").shape[0]
p
# Out:
# 82

# %%
# Total matches winned by Mimbai Indians in Mumbai
w = df[df.city == 'Mumbai'].query("team1 == 'Mumbai Indians' or team2 == 'Mumbai Indians'")[df[df.city == 'Mumbai'].query("team1 == 'Mumbai Indians' or team2 == 'Mumbai Indians'").winner == 'Mumbai Indians'].shape[0]
w
# Out:
# 53

# %%
y = [53,82-53]

# %%
plt.pie(y,autopct = '%.2f%%',labels = ['win','loss'])
plt.title("%distribution of Mumbai Indians in its homeground")
plt.show()

# %% [raw]
# It represents 64.63% matches are wined by Mumbai Indians in Mumbai

# %% [markdown]
# ##### How Many times Runrise Hyd wons?

# %%
df[df.winner == 'Sunrisers Hyderabad'].shape[0]
# Out:
# 58

# %%
len(df.query("winner == 'Sunrisers Hyderabad'"))
# Out:
# 58

# %%
(df.winner == 'Sunrisers Hyderabad').sum()
# Out:
# 58

# %%
df.winner.value_counts()['Sunrisers Hyderabad']
# Out:
# 58

# %% [markdown]
# ##### How Many times Runrise Hyd wons by runs more than 35

# %%
df.query("winner == 'Sunrisers Hyderabad' and win_by_runs > 35").shape[0]
# Out:
# 4

# %%
len(df.query("winner == 'Sunrisers Hyderabad' and win_by_runs > 35"))
# Out:
# 4

# %% [markdown]
# ##### Plot % of how many times dl_applied?

# %%
df.dl_applied.value_counts().plot.pie(autopct = '%.2f%%')
plt.show()

# %% [markdown]
# ##### Show entries where toss_winner is winner? do comparative visualization of it

# %%
df[df.toss_winner == df.winner]
# Out:
#         id    Season           city     date                        team1  \
# 1        2  IPL-2017           Pune   6/4/17               Mumbai Indians
# 2        3  IPL-2017         Rajkot   7/4/17                Gujarat Lions
# 3        4  IPL-2017         Indore   8/4/17       Rising Pune Supergiant
# 4        5  IPL-2017      Bangalore   8/4/17  Royal Challengers Bangalore
# 5        6  IPL-2017      Hyderabad   9/4/17                Gujarat Lions
# ..     ...       ...            ...      ...                          ...
# 750  11346  IPL-2019         Mohali   5/5/19          Chennai Super Kings
# 751  11347  IPL-2019         Mumbai   5/5/19        Kolkata Knight Riders
# 753  11413  IPL-2019  Visakhapatnam   8/5/19          Sunrisers Hyderabad
# 754  11414  IPL-2019  Visakhapatnam  10/5/19               Delhi Capitals
# 755  11415  IPL-2019      Hyderabad  12/5/19               Mumbai Indians
#
#                       team2                  toss_winner toss_decision  \
# ...

# %%
df.query("toss_winner == winner").winner.value_counts().plot(kind = 'bar')
plt.show()

# %% [markdown]
# ##### How Many times each team won till now?

# %%
df.winner.value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Delhi Capitals                  10
# Rising Pune Supergiant          10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# Name: winner, dtype: int64

# %%
df.winner.value_counts().plot(kind = 'bar')
plt.show()

# %%
df.winner.value_counts().plot(kind = 'pie',autopct = '%.f%%',radius = 3)
plt.show()

# %% [markdown]
# ##### for which city maximum matches played?

# %%
df.city.value_counts().index[0]
# Out:
# 'Mumbai'

# %% [markdown]
# ##### visualize when toss winning team will be the winner either if bat first or field first

# %%
df[df.toss_winner == df.winner].toss_decision.value_counts()
# Out:
# field    259
# bat      134
# Name: toss_decision, dtype: int64

# %%
plt.bar(df[df.toss_winner == df.winner].toss_decision.value_counts().index,df[df.toss_winner == df.winner].toss_decision.value_counts().values)
# Out:
# <BarContainer object of 2 artists>

# %%
win = pd.DataFrame()
for i in df.groupby('Season'):
    win = win.append(i[1].query("toss_winner == winner").toss_decision.value_counts())
   
data = []
win.index = df.Season.unique()
ind = win.index.str.split('-',expand = True)
for i in range(len(ind)):
    data.append(ind[i][1])
win.index = data
win
# Out:
#        bat  field
# 2017   9.0   19.0
# 2008  19.0   14.0
# 2009  21.0   10.0
# 2010  11.0   27.0
# 2011  15.0   18.0
# 2012  21.0   15.0
# 2013   6.0   24.0
# 2014  14.0   14.0
# 2015   2.0   32.0
# 2016   6.0   28.0
# 2018   5.0   27.0
# 2019   5.0   31.0

# %%
win.plot(kind='bar')
plt.show()

# %% [raw]
# Here, I have clean and process data to get desired result. also here data visualization in different perspectives is done to represent results.
